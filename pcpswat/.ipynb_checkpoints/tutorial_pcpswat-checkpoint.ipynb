# %% [markdown]
# # Tutorial para uso de pcpswat.py
#
# O pacote pcpswat contém diversas funções para processamento da precipitação para uso no SWAT. Este notebook contém informações para uso do pacote.
#
# O pacote requer alguns módulos especiais para python, que geralmente podem ser instalados mais facilmente utilizando o gerenciador de pacodes anaconda. Alguns pacotes necessários para algumas funcões especiais são:
# 1. Pandas
# 2. Numpy
# 3. Scipy
# 4. Geopandas: esse pode ser chatinho de instalar. Ele é necessário somente caso seja utilizado arquivos shape
#
# Para executar sem precisar instalar clique no icone do google colab abaixo
#
# <a href="https://colab.research.google.com/github/SWAT-Brasil/util/blob/master/pcpswat/tutorial_pcpswat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# Utilize ```SHIFT+ENTER``` para executar a célula.

# %%
# Verifica se esta rodando no COLAB e instala dependencias
def init_colab_env():
  """ prepara ambiente para uso no COLAB """
  # !pip install geopandas
  # !git clone https://github.com/SWAT-Brasil/util.git
  # !cp util/pcpswat/pcpswat.py .
  # !mkdir test
  # !cp -r util/pcpswat/test/* ./test

running_in_colab = 'google.colab' in str(get_ipython())
if running_in_colab:
  init_colab_env()

# %%
# Carrega pacotes do python. Voce pode instalar com o pip ou utilizando anaconda. Anaconda é mais amigavel para uso e instalação dos pacotes, e funciona bem em windows/linux
# %matplotlib inline
import geopandas as gpd
import pyproj
import pandas as pd
import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import pcpswat

# %% [markdown]
# # Interpolação

# %%
# Caminho para arquivos de entrada e diretorio de saida
# Neste diretorios estão alguns arquivos de exemplo
shape_file = './test/example_1/shape/subs1.shp'
index_file = './test/example_1/pcp/pcp.txt'
output_folder = './test/example_1/out'

# %%
# Le shapefile e obtem os centroides
# TODO: verificar se o waring é valido ou não neste caso
pts_to_interpolate, shape = pcpswat.get_centroid_from_shape(shape_file)
# Out:
# /media/jairo/Dados/Jairo/Projetos/SWAT/git/util/pcpswat/pcpswat.py:125: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = shape.centroid
# /media/jairo/Dados/Jairo/Projetos/SWAT/git/util/pcpswat/pcpswat.py:126: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   pts_to_interpolate = np.array(list(shape.centroid.map(lambda p: [p.x, p.y])))

# %%
# Carrega dados observados
observed_data_index, observed_data, observed_pts = pcpswat.read_pcp(index_file)
# Out:
# Lendo ./test/example_1/pcp/pcp.txt
# Lendo ./test/example_1/pcp/p83076.txt
# Lendo ./test/example_1/pcp/p83179.txt
# Lendo ./test/example_1/pcp/p83235.txt
# Lendo ./test/example_1/pcp/p83236.txt
# Lendo ./test/example_1/pcp/p1045006.txt
# Lendo ./test/example_1/pcp/p1143005.txt
# Lendo ./test/example_1/pcp/p1144005.txt
# Lendo ./test/example_1/pcp/p1144027.txt
# Lendo ./test/example_1/pcp/p1145001.txt
# Lendo ./test/example_1/pcp/p1145004.txt
# Lendo ./test/example_1/pcp/p1145013.txt
# Lendo ./test/example_1/pcp/p1145014.txt
# Lendo ./test/example_1/pcp/p1145019.txt
# Lendo ./test/example_1/pcp/p1145020.txt
# Lendo ./test/example_1/pcp/p1244011.txt
# Lendo ./test/example_1/pcp/p1244019.txt
# Lendo ./test/example_1/pcp/p1245004.txt
# Lendo ./test/example_1/pcp/p1245014.txt
# Lendo ./test/example_1/pcp/p1245015.txt
# Lendo ./test/example_1/pcp/p1245016.txt

# %%
# Mostra figura com shape e pontos observados e centroides
f, ax = plt.subplots(1,figsize=(15,8))
f.suptitle('Shape com pontos observados e interpolados')
pcp_pts = gpd.GeoDataFrame(geometry=gpd.points_from_xy(observed_pts[:,0],observed_pts[:,1]))
ipcp_pts = gpd.GeoDataFrame(geometry=gpd.points_from_xy(pts_to_interpolate[:,0],pts_to_interpolate[:,1]))
shape.plot(ax=ax)
pcp_pts.plot(ax=ax, color='red')
ipcp_pts.plot(ax=ax, color='black')

from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='black', lw=4)]

#fig, ax = plt.subplots()
#lines = ax.plot(data)
ax.legend(custom_lines, ['observado','interpolado'])

# %%
observed_data[0].index[0]
# Out:
# Timestamp('2000-01-01 00:00:00')

# %%
# Interpolação
interpolated_data = pcpswat.interpolate(observed_pts, observed_data, pts_to_interpolate, method='nearest')
# Out:
#  |###-----------------------------------------------| 6.4%
#  |######--------------------------------------------| 13.3%
#  |##########----------------------------------------| 20.2%
#  |#############-------------------------------------| 27.2%
#  |#################---------------------------------| 34.1%
#  |####################------------------------------| 41.2%
#  |########################--------------------------| 48.1%
#  |###########################-----------------------| 54.8%
#  |###############################-------------------| 62.3%
#  |##################################----------------| 69.2%
#  |######################################------------| 76.2%
#  |#########################################---------| 82.8%
#  |############################################------| 89.6%
#  |###############################################---| 95.7%
#  |##################################################| 100.0%

# %%
# Gera e salva pcp.txt para interpolado

# Cria dados de indice para precipitacao interpolada    
interpolated_index = pcpswat.create_pcp_index(pts_to_interpolate)
# salva indice e dados interpolados
pcpswat.save_pcp(interpolated_index, interpolated_data, output_folder)
# Out:
# Salvando ./test/example_1/out/pcp.txt
# Salvando ./test/example_1/out/ipcp0001.txt
# Salvando ./test/example_1/out/ipcp0002.txt
# Salvando ./test/example_1/out/ipcp0003.txt
# Salvando ./test/example_1/out/ipcp0004.txt
# Salvando ./test/example_1/out/ipcp0005.txt
# Salvando ./test/example_1/out/ipcp0006.txt
# Salvando ./test/example_1/out/ipcp0007.txt
# Salvando ./test/example_1/out/ipcp0008.txt
# Salvando ./test/example_1/out/ipcp0009.txt
# Salvando ./test/example_1/out/ipcp0010.txt
# Salvando ./test/example_1/out/ipcp0011.txt
# Salvando ./test/example_1/out/ipcp0012.txt
# Salvando ./test/example_1/out/ipcp0013.txt
# Salvando ./test/example_1/out/ipcp0014.txt
# Salvando ./test/example_1/out/ipcp0015.txt
# Salvando ./test/example_1/out/ipcp0016.txt
# Salvando ./test/example_1/out/ipcp0017.txt
# Salvando ./test/example_1/out/ipcp0018.txt
# Salvando ./test/example_1/out/ipcp0019.txt
# Salvando ./test/example_1/out/ipcp0020.txt
# Salvando ./test/example_1/out/ipcp0021.txt
# Salvando ./test/example_1/out/ipcp0022.txt
# Salvando ./test/example_1/out/ipcp0023.txt
# Salvando ./test/example_1/out/ipcp0024.txt
# Salvando ./test/example_1/out/ipcp0025.txt
# Salvando ./test/example_1/out/ipcp0026.txt
# Salvando ./test/example_1/out/ipcp0027.txt
# Salvando ./test/example_1/out/ipcp0028.txt
# Salvando ./test/example_1/out/ipcp0029.txt
# Salvando ./test/example_1/out/ipcp0030.txt
# Salvando ./test/example_1/out/ipcp0031.txt
# Salvando ./test/example_1/out/ipcp0032.txt
# Salvando ./test/example_1/out/ipcp0033.txt
# Salvando ./test/example_1/out/ipcp0034.txt
# Salvando ./test/example_1/out/ipcp0035.txt
# Salvando ./test/example_1/out/ipcp0036.txt
# Salvando ./test/example_1/out/ipcp0037.txt

# %% [markdown]
# ### Visualização da interpolação em grid
# Aqui tem um exemplo para apresentar o resultado da interpolãção em formato de uma imagem. Isso não deve ser de uso normal, mas é legal para ver o resultado. Isso é um pouco mais complicado que o uso normal, e é dividido em 3 etapas: definição de pontos a sererm interpolados com a grade, rearranjo dos dados observados e rearranjo do dados interpolados para apresenteção.

# %%
# Preparação do grid para definir os pontos que devem ser interpolados

# numero de divisoes da grid (para x e y)
grid_n = 100
# encontra limites da area a ser interpolada
x_min, y_min, x_max, y_max = shape.total_bounds
ox_min, oy_min, ox_max, oy_max = pcp_pts.total_bounds
if ox_min < x_min:
    x_min = ox_min
if oy_min < y_min:
    y_min = oy_min
if ox_max > x_max:
    x_max = ox_max
if oy_max > y_max:
    y_max = oy_max
# aplica margens
margin_x = (0.05 * (x_max - x_min))
margin_y = (0.05 * (y_max - y_min))
x_max += margin_x
y_max += margin_y
x_min -= margin_x
y_min -= margin_y

# Gera grid
grid_x, grid_y = np.mgrid[x_min:x_max:grid_n*1j, y_min:y_max:grid_n*1j]
# transforma grid de pontos para sequencia de pontos (x,y)
grid_points = np.column_stack([grid_x.ravel(), grid_y.ravel()])

# %%
# Prepara dados de entrada para somente 1 ponto temporal

# valor do index equivalente ao tempo para ser apresentado
index = 0
print('Ponto a ser interpolado: {}'.format(observed_data[0].index[index]))

# recorta somente os dados que equivalente ao tempo index
sliced_observed_data = np.array(observed_data).T[index].reshape(-1,1)
# ajusta formato dos dados
sliced_observed_data = pd.DataFrame(sliced_observed_data.T)
sliced_observed_data = [sliced_observed_data[col] for col in sliced_observed_data]
# Out:
# Ponto a ser interpolado: 2000-01-01 00:00:00

# %%
# Interpola
interpolated = pcpswat.interpolate(observed_pts, sliced_observed_data, grid_points, method='idw')
# Out:
#  |##################################################| 100.0%

# %%
# ajusta formato de saida
interpolated = interpolated.to_numpy()
# converte saida para formato de imagem
interpolated = interpolated[0].reshape(grid_n, grid_n)

# %%
# Apresenta inteprolacao
f, ax = plt.subplots(1,figsize=(15,8))
f.suptitle('Interpolacao')
# mapa de cores da interpolacao
extent = [x_min, x_max, y_min, y_max]
plt.imshow(interpolated.T,extent=extent, origin='lower')
plt.colorbar()

# shape com os contornos
shape.geometry.boundary.plot(color=None,edgecolor='k',linewidth = 0.5,ax=ax)

# Pontos observados
pcp_pts.plot(ax=ax, color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exemplo na linha de comando
# Também é possivel utilizar o pcpswat diretamente na linha de comando para fazer a interpolação. Retire a exclamação do inicio caso utilize diretamente na linha de comando.

# %%
# help
# !python pcpswat.py -h
# Out:
# Ferramenta de interpolacao de precipitacao para SWAT 0.1.0
# usage: pcpswat.py [-h] [-shape SHAPE] [-interpolate INTERPOLATE]
#                   [-method METHOD] [-savefig]
#                   pcp_file destination_folder
#
# Ferramenta de interpolação de precipitação para SWAT
#
# positional arguments:
#   pcp_file              pcp index file
#   destination_folder    destination folder
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -shape SHAPE          shape file para obter o centroide automaticamente
#   -interpolate INTERPOLATE
#                         arquivo com os pontos a serem interpolados
#   -method METHOD        metodo de interpolacao
#   -savefig              salva arquivo com imagem dos pontos observados,
#                         interpolados e shape

# %%
# Exemplo para interpolar com pontos fornecidos manualmente (-interpolate) e define o metodo de interpolacao como nearest
# !python pcpswat.py ./test/example_1/pcp/pcp.txt ./test/example_1/out/ -interpolate ./test/example_1/pcp/pcp_to_interpolate.txt -method 'nearest'
# Out:
# Ferramenta de interpolacao de precipitacao para SWAT 0.1.0
# Pontos a interpolar definidos manualmente
# Lendo ./test/example_1/pcp/pcp_to_interpolate.txt
# Carregando dados de precipitacao
# Lendo ./test/example_1/pcp/pcp.txt
# Lendo ./test/example_1/pcp/p83076.txt
# Lendo ./test/example_1/pcp/p83179.txt
# Lendo ./test/example_1/pcp/p83235.txt
# Lendo ./test/example_1/pcp/p83236.txt
# Lendo ./test/example_1/pcp/p1045006.txt
# Lendo ./test/example_1/pcp/p1143005.txt
# Lendo ./test/example_1/pcp/p1144005.txt
# Lendo ./test/example_1/pcp/p1144027.txt
# Lendo ./test/example_1/pcp/p1145001.txt
# Lendo ./test/example_1/pcp/p1145004.txt
# Lendo ./test/example_1/pcp/p1145013.txt
# Lendo ./test/example_1/pcp/p1145014.txt
# Lendo ./test/example_1/pcp/p1145019.txt
# Lendo ./test/example_1/pcp/p1145020.txt
# Lendo ./test/example_1/pcp/p1244011.txt
# Lendo ./test/example_1/pcp/p1244019.txt
# Lendo ./test/example_1/pcp/p1245004.txt
# Lendo ./test/example_1/pcp/p1245014.txt
# Lendo ./test/example_1/pcp/p1245015.txt
# Lendo ./test/example_1/pcp/p1245016.txt
# Verificando dados...
# Serie p83076.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p83179.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p83235.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p83236.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1045006.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1143005.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1144005.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1144027.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145001.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145004.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145013.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145014.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145019.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145020.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1244011.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1244019.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245004.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245014.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245015.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245016.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Periodo de dados final: 2000-01-01 00:00:00 - 2016-12-31 00:00:00
# Interpolando utilizando metodo nearest
#  |##################################################| 100.0%
# Salvando dados interpolados
# Salvando ./test/example_1/out/pcp.txt
# Salvando ./test/example_1/out/aaaaa.txt
# Salvando ./test/example_1/out/bbbbb.txt
# Salvando ./test/example_1/out/ccccc.txt
# Salvando ./test/example_1/out/ddddd.txt
# Salvando ./test/example_1/out/eeeee.txt
# Salvando ./test/example_1/out/fffff.txt
# Salvando ./test/example_1/out/ggggg.txt
# Salvando ./test/example_1/out/hhhhh.txt
# Salvando ./test/example_1/out/iiiii.txt
# Salvando ./test/example_1/out/jjjj.txt

# %%
# Interpola utilizando as centroids do arquivo shape e salva um figura com o shape e pontos observado e interpolados, e utiliza metodo idw
# !python pcpswat.py ./test/example_1/pcp/pcp.txt ./test/example_1/out/  -shape ./test/example_1/shape/subs1.shp -savefig -method 'idw'
# Out:
# Ferramenta de interpolacao de precipitacao para SWAT 0.1.0
# Obtendo pontos a interpolar do arquivo shape
# Carregando dados de precipitacao
# Lendo ./test/example_1/pcp/pcp.txt
# Lendo ./test/example_1/pcp/p83076.txt
# Lendo ./test/example_1/pcp/p83179.txt
# Lendo ./test/example_1/pcp/p83235.txt
# Lendo ./test/example_1/pcp/p83236.txt
# Lendo ./test/example_1/pcp/p1045006.txt
# Lendo ./test/example_1/pcp/p1143005.txt
# Lendo ./test/example_1/pcp/p1144005.txt
# Lendo ./test/example_1/pcp/p1144027.txt
# Lendo ./test/example_1/pcp/p1145001.txt
# Lendo ./test/example_1/pcp/p1145004.txt
# Lendo ./test/example_1/pcp/p1145013.txt
# Lendo ./test/example_1/pcp/p1145014.txt
# Lendo ./test/example_1/pcp/p1145019.txt
# Lendo ./test/example_1/pcp/p1145020.txt
# Lendo ./test/example_1/pcp/p1244011.txt
# Lendo ./test/example_1/pcp/p1244019.txt
# Lendo ./test/example_1/pcp/p1245004.txt
# Lendo ./test/example_1/pcp/p1245014.txt
# Lendo ./test/example_1/pcp/p1245015.txt
# Lendo ./test/example_1/pcp/p1245016.txt
# Salvando figura ./test/example_1/out/fig.png
# Verificando dados...
# Serie p83076.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p83179.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p83235.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p83236.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1045006.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1143005.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1144005.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1144027.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145001.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145004.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145013.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145014.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145019.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1145020.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1244011.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1244019.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245004.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245014.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245015.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Serie p1245016.txt, periodo: (2000-01-01 00:00:00 - 2016-12-31 00:00:00), numero de pontos: 6210
# Periodo de dados final: 2000-01-01 00:00:00 - 2016-12-31 00:00:00
# Interpolando utilizando metodo idw
#  |##################################################| 100.0%
# Salvando dados interpolados
# Salvando ./test/example_1/out/pcp.txt
# Salvando ./test/example_1/out/ipcp0001.txt
# Salvando ./test/example_1/out/ipcp0002.txt
# Salvando ./test/example_1/out/ipcp0003.txt
# Salvando ./test/example_1/out/ipcp0004.txt
# Salvando ./test/example_1/out/ipcp0005.txt
# Salvando ./test/example_1/out/ipcp0006.txt
# Salvando ./test/example_1/out/ipcp0007.txt
# Salvando ./test/example_1/out/ipcp0008.txt
# Salvando ./test/example_1/out/ipcp0009.txt
# Salvando ./test/example_1/out/ipcp0010.txt
# Salvando ./test/example_1/out/ipcp0011.txt
# Salvando ./test/example_1/out/ipcp0012.txt
# Salvando ./test/example_1/out/ipcp0013.txt
# Salvando ./test/example_1/out/ipcp0014.txt
# Salvando ./test/example_1/out/ipcp0015.txt
# Salvando ./test/example_1/out/ipcp0016.txt
# Salvando ./test/example_1/out/ipcp0017.txt
# Salvando ./test/example_1/out/ipcp0018.txt
# Salvando ./test/example_1/out/ipcp0019.txt
# Salvando ./test/example_1/out/ipcp0020.txt
# Salvando ./test/example_1/out/ipcp0021.txt
# Salvando ./test/example_1/out/ipcp0022.txt
# Salvando ./test/example_1/out/ipcp0023.txt
# Salvando ./test/example_1/out/ipcp0024.txt
# Salvando ./test/example_1/out/ipcp0025.txt
# Salvando ./test/example_1/out/ipcp0026.txt
# Salvando ./test/example_1/out/ipcp0027.txt
# Salvando ./test/example_1/out/ipcp0028.txt
# Salvando ./test/example_1/out/ipcp0029.txt
# Salvando ./test/example_1/out/ipcp0030.txt
# Salvando ./test/example_1/out/ipcp0031.txt
# Salvando ./test/example_1/out/ipcp0032.txt
# Salvando ./test/example_1/out/ipcp0033.txt
# Salvando ./test/example_1/out/ipcp0034.txt
# Salvando ./test/example_1/out/ipcp0035.txt
# Salvando ./test/example_1/out/ipcp0036.txt
# Salvando ./test/example_1/out/ipcp0037.txt
